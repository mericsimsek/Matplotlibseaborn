# %%
import seaborn as sns
fm=sns.load_dataset("fmri")
df=fm.copy()
df.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
df.groupby("signal")["timepoint"].describe()
# Out:
#            count  mean  std   min   25%   50%   75%   max
# signal
# -0.255486    1.0  12.0  NaN  12.0  12.0  12.0  12.0  12.0
# -0.238474    1.0  11.0  NaN  11.0  11.0  11.0  11.0  11.0
# -0.224351    1.0  13.0  NaN  13.0  13.0  13.0  13.0  13.0
# -0.181241    1.0   8.0  NaN   8.0   8.0   8.0   8.0   8.0
# -0.178510    1.0  12.0  NaN  12.0  12.0  12.0  12.0  12.0
# ...          ...   ...  ...   ...   ...   ...   ...   ...
#  0.455575    1.0   5.0  NaN   5.0   5.0   5.0   5.0   5.0
#  0.460896    1.0   5.0  NaN   5.0   5.0   5.0   5.0   5.0
#  0.476055    1.0   5.0  NaN   5.0   5.0   5.0   5.0   5.0
#  0.494787    1.0   7.0  NaN   7.0   7.0   7.0   7.0   7.0
#  0.564985    1.0   6.0  NaN   6.0   6.0   6.0   6.0   6.0
#
# [1064 rows x 8 columns]

# %%
sns.lineplot(x="timepoint",y="signal",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event",markers=True , dashes=True,data=df)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
