# %%
import seaborn as sns
ir=sns.load_dataset("iris")
import pandas as pd
df=ir.copy()
df2=fl.copy()

# %%
sns.pairplot(df,hue ="species")

# %%
sns.pairplot(df,kind ="reg")

# %%
fl=sns.load_dataset("flights")
df2=fl.copy()
df2=df2.pivot("month","year","passengers")
# Out:
# C:\Users\meric\AppData\Local\Temp\ipykernel_6252\3070123213.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df2=df2.pivot("month","year","passengers")

# %%
sns.heatmap(df2,annot=True,fmt="d",linewidths=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.heatmap(df2,annot=True,fmt="d",linewidths=5)
#
# NameError: name 'sns' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sns.heatmap(df2,annot=True,linewidths=5)
#
# NameError: name 'sns' is not defined
